# %%
#Must Have scikit-learn version 1.1.0 installed beforehand
# !pip install octis

# %%
import json
import pickle
# Helper function to load token list from pickle file and load topic words from json file
def load_token_list_and_topics(token_file='token_list.pkl', topics_file='topic_words.json'):
    # Load token list from pickle
    with open('PickleFiles/Tokens/' + token_file, 'rb') as f:
        token_list = pickle.load(f)

    # Load topic words from JSON
    with open('PickleFiles/Topics/' + topics_file, 'r') as f:
        topic_words = json.load(f)

    return token_list, topic_words

# %%
###Quick note about the order of the models: the order of the models goes in alphabetical order of the file names, so all_corpus_again would be before fan_corpus_only. For every model, all_configs is first, followed by stop_words, followed by hdbscan and finally finished with umap

# %%
##BREAK

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_again_tokens_all_configs.pkl',
                                                     'all_corpus_again_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.376860428941195

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_again_tokens_stop_words.pkl',
                                                     'all_corpus_again_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.3372796864984524

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_again_tokens_stop_words_hdbscan.pkl',
                                                     'all_corpus_again_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.40342559514549475

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_again_tokens_stop_words_umap.pkl',
                                                     'all_corpus_again_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.3372796864984524

# %%
#Break

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_tokens_all_configs.pkl',
                                                     'all_corpus_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4399290546130862

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_tokens_stop_words.pkl',
                                                     'all_corpus_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.42875325109059637

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_tokens_stop_words_hdbscan.pkl',
                                                     'all_corpus_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.3915508087902008

# %%
token_list, topic_words = load_token_list_and_topics('all_corpus_tokens_stop_words_umap.pkl',
                                                     'all_corpus_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.40392540549281897

# %%
#Break

# %%
token_list, topic_words = load_token_list_and_topics('fan_and_fiction_tokens_all_configs.pkl',
                                                     'fan_and_fiction_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.3724660860034322

# %%
token_list, topic_words = load_token_list_and_topics('fan_and_fiction_tokens_stop_words.pkl',
                                                     'fan_and_fiction_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.39293744030094546

# %%
token_list, topic_words = load_token_list_and_topics('fan_and_fiction_tokens_stop_words_hdbscan.pkl',
                                                     'fan_and_fiction_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.41538815304139

# %%
token_list, topic_words = load_token_list_and_topics('fan_and_fiction_tokens_stop_words_umap.pkl',
                                                     'fan_and_fiction_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4264205203349266

# %%
#Break

# %%
token_list, topic_words = load_token_list_and_topics('fan_tokens_all_configs.pkl',
                                                     'fan_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4872462460638685

# %%
token_list, topic_words = load_token_list_and_topics('fan_tokens_stop_words.pkl',
                                                     'fan_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.5958840922751167

# %%
token_list, topic_words = load_token_list_and_topics('fan_tokens_stop_words_hdbscan.pkl',
                                                     'fan_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4337482915284432

# %%
token_list, topic_words = load_token_list_and_topics('fan_tokens_stop_words_umap.pkl',
                                                     'fan_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.5615579269069118

# %%
###BREAK

# %%
token_list, topic_words = load_token_list_and_topics('fiction_tokens_all_configs.pkl',
                                                     'fiction_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4381547240132947

# %%
token_list, topic_words = load_token_list_and_topics('fiction_tokens_stop_words.pkl',
                                                     'fiction_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.3888868340658594

# %%
token_list, topic_words = load_token_list_and_topics('fiction_tokens_stop_words_hdbscan.pkl',
                                                     'fiction_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.36936814068623147

# %%
token_list, topic_words = load_token_list_and_topics('fiction_tokens_stop_words_umap.pkl',
                                                     'fiction_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.3566118144852333

# %%
###Break

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fan_tokens_all_configs.pkl',
                                                     'grimm_again_and_fan_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.44189133607965725

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fan_tokens_stop_words.pkl',
                                                     'grimm_again_and_fan_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4539372437862932

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fan_tokens_stop_words_hdbscan.pkl',
                                                     'grimm_again_and_fan_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.47247022586790377

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fan_tokens_stop_words_umap.pkl',
                                                     'grimm_again_and_fan_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4539372437862932

# %%
###Break

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fiction_tokens_all_configs.pkl',
                                                     'grimm_again_and_fiction_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4171836650812356

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fiction_tokens_stop_words.pkl',
                                                     'grimm_again_and_fiction_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.37264331869634776

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fiction_tokens_stop_words_hdbscan.pkl',
                                                     'grimm_again_and_fiction_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.3594067916345416

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_and_fiction_tokens_stop_words_umap.pkl',
                                                     'grimm_again_and_fiction_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.37264331869634776

# %%
###Break

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_tokens_all_configs.pkl',
                                                     'grimm_again_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4950329240974002

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_tokens_stop_words.pkl',
                                                     'grimm_again_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.5625046137440477

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_tokens_stop_words_hdbscan.pkl',
                                                     'grimm_again_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4564727864186764

# %%
token_list, topic_words = load_token_list_and_topics('grimm_again_tokens_stop_words_umap.pkl',
                                                     'grimm_again_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.48512264885112916

# %%
###Break

# %%
token_list, topic_words = load_token_list_and_topics('grimm_tokens_all_configs.pkl',
                                                     'grimm_topics_all_configs.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4715667218242559

# %%
token_list, topic_words = load_token_list_and_topics('grimm_tokens_stop_words.pkl',
                                                     'grimm_topics_stop_words.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.4043307736740826

# %%
token_list, topic_words = load_token_list_and_topics('grimm_tokens_stop_words_hdbscan.pkl',
                                                     'grimm_topics_stop_words_hdbscan.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.48205797048375093

# %%
token_list, topic_words = load_token_list_and_topics('grimm_tokens_stop_words_umap.pkl',
                                                     'grimm_topics_stop_words_umap.json')

from octis.evaluation_metrics.coherence_metrics import Coherence

#Initialize coherence metric model
coherence_model = Coherence(texts=token_list,
                            topk=10,
                            measure='c_v')

coherence_score = coherence_model.score({"topics": topic_words})
print("Coherence (C_v:)", coherence_score)
# Out:
# Coherence (C_v:) 0.5335260610943757
